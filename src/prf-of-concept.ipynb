# %% [markdown]
# Modified from the [NVFlare Hello PyTorch example](https://github.com/NVIDIA/NVFlare/tree/main/examples/hello-world/hello-pt)

# %% [markdown]
# ## Run an NVFlare Job
# Now that we have defined the FedAvg controller to run our federated compute workflow on the FL server, and our client training script to receive the global models, run local training, and send the results back to the FL server, we can put everything together using NVFlare's Job API.

# %% [markdown]
# #### 2. Define a FedJob Recipe

# %%
from server.model import FusionNet

from nvflare.app_opt.pt.recipes.fedavg import FedAvgRecipe
from nvflare.recipe import SimEnv
from nvflare.recipe import add_experiment_tracking
import torch 
n_clients = 2
num_rounds = 4
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model = FusionNet().to(device)

recipe = FedAvgRecipe(
    name="MEM_SAN_FedCollab", # MEM - Memphis, SAN - San Diego
    min_clients=n_clients,
    num_rounds=num_rounds,
    initial_model=model,
    train_script="multi-client-sim.py",
)

# %% [markdown]
# #### 3. Add experiment tracking

# %%
add_experiment_tracking(recipe, tracking_type="tensorboard")

# %% [markdown]
# #### 4. Run Job
# Here, we run the job in a simulation environment.

# %%
env = SimEnv(num_clients=n_clients)
run = recipe.execute(env)
print()
print("Job Status is:", run.get_status())
print("Result can be found in :", run.get_result())
print()
# Out:
# 2026-01-09 02:17:16,841 - INFO - model selection weights control: {}
# 2026-01-09 02:17:17,479 - INFO - Tensorboard records can be found in /tmp/nvflare/simulation/MEM_SAN_FedCollab/server/simulate_job/tb_events you can view it using `tensorboard --logdir=/tmp/nvflare/simulation/MEM_SAN_FedCollab/server/simulate_job/tb_events`
# 2026-01-09 02:17:17,479 - INFO - Tensorboard records can be found in /tmp/nvflare/simulation/MEM_SAN_FedCollab/server/simulate_job/tb_events you can view it using `tensorboard --logdir=/tmp/nvflare/simulation/MEM_SAN_FedCollab/server/simulate_job/tb_events`
# 2026-01-09 02:17:17,479 - INFO - Initializing ScatterAndGather workflow for Federated Averaging.
# 2026-01-09 02:17:17,479 - INFO - Both source_ckpt_file_full_name and ckpt_preload_path are not provided. Using the default model weights initialized on the persistor side.
# 2026-01-09 02:17:17,480 - INFO - Beginning ScatterAndGather training phase.
# 2026-01-09 02:17:17,480 - INFO - Round 0 started.
# 2026-01-09 02:17:21,092 - INFO - start task run() with full path: /tmp/nvflare/simulation/MEM_SAN_FedCollab/site-1/simulate_job/app_site-1/custom/multi-client-sim.py
# 2026-01-09 02:17:21,093 - INFO - start task run() with full path: /tmp/nvflare/simulation/MEM_SAN_FedCollab/site-2/simulate_job/app_site-2/custom/multi-client-sim.py
# 2026-01-09 02:17:21,212 - INFO - --- site-2: San Diego ---
# 2026-01-09 02:17:21,212 - INFO - --- site-1: Memphis ---
# 2026-01-09 02:17:21,399 - INFO - execute for task (train)
# 2026-01-09 02:17:21,399 - INFO - send data to peer
# 2026-01-09 02:17:21,399 - INFO - sending payload to peer
# 2026-01-09 02:17:21,400 - INFO - Waiting for result from peer
# 2026-01-09 02:17:21,411 - INFO - execute for task (train)
# 2026-01-09 02:17:21,412 - INFO - send data to peer
# 2026-01-09 02:17:21,412 - INFO - sending payload to peer
# 2026-01-09 02:17:21,412 - INFO - Waiting for result from peer
# 2026-01-09 02:17:21,864 - INFO - Probabilities: tensor([[0.5218],
#         [0.4716],
#         [0.5918],
#         [0.4950],
#         [0.5168],
#         [0.4839],
#         [0.5774],
#         [0.4999],
#         [0.4297],
#         [0.4790],
#         [0.5113],
#         [0.4465],
#         [0.5874],
#         [0.5347],
#         [0.5918],
#         [0.5380],
#         [0.4570],
#         [0.4074],
#         [0.5715],
#         [0.5248],
#         [0.5165],
#         [0.5501],
#         [0.6591],
#         [0.5574],
#         [0.5170],
#         [0.5957]])
# 2026-01-09 02:17:21,864 - INFO - Accuracy of the network on the 26 test subjects from Cohort A: 961 %
# 2026-01-09 02:17:21,865 - INFO - Probabilities: tensor([[0.4960],
#         [0.4782],
#         [0.5992],
#         [0.5649],
#         [0.6200],
#         [0.5417],
#         [0.5488],
#         [0.5858],
#         [0.5202],
#         [0.5536],
#         [0.5610],
#         [0.5480],
#         [0.5748],
#         [0.5405],
#         [0.5100],
#         [0.4567],
#         [0.5295],
#         [0.5657],
#         [0.4043],
#         [0.4421],
#         [0.4598],
#         [0.4943],
#         [0.5573],
#         [0.4796],
#         [0.4468],
#         [0.5493]])
# 2026-01-09 02:17:21,865 - INFO - Accuracy of the network on the 26 test subjects from Cohort A: 961 %
# 2026-01-09 02:17:22,373 - INFO - Memphis Hospital site_name: site-1
# 2026-01-09 02:17:22,374 - INFO - current_round=0
# 2026-01-09 02:17:22,377 - INFO - San Diego Hospital corresponds to site-2
# 2026-01-09 02:17:22,378 - ERROR - Traceback (most recent call last):
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_common/executors/task_script_runner.py", line 54, in run
#     runpy.run_path(self.script_full_path, run_name="__main__")
#   File "<frozen runpy>", line 287, in run_path
#   File "<frozen runpy>", line 98, in _run_module_code
#   File "<frozen runpy>", line 88, in _run_code
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-1/simulate_job/app_site-1/custom/multi-client-sim.py", line 90, in <module>
#     main()
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-1/simulate_job/app_site-1/custom/multi-client-sim.py", line 69, in main
#     new_params, steps = update_model(
#                         ^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/src/clients/memphis/client.py", line 67, in update_model
#     cost = loss(output['logits'], labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/loss.py", line 850, in forward
#     return F.binary_cross_entropy_with_logits(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/functional.py", line 3589, in binary_cross_entropy_with_logits
#     raise ValueError(
# ValueError: Target size (torch.Size([16])) must be the same as input size (torch.Size([16, 1]))
#
# 2026-01-09 02:17:22,378 - ERROR - fire abort event
# 2026-01-09 02:17:22,379 - ERROR - ask to abort job: reason: '/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-1/simulate_job/app_site-1/custom/multi-client-sim.py' is aborted, Traceback (most recent call last):
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_common/executors/task_script_runner.py", line 54, in run
#     runpy.run_path(self.script_full_path, run_name="__main__")
#   File "<frozen runpy>", line 287, in run_path
#   File "<frozen runpy>", line 98, in _run_module_code
#   File "<frozen runpy>", line 88, in _run_code
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-1/simulate_job/app_site-1/custom/multi-client-sim.py", line 90, in <module>
#     main()
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-1/simulate_job/app_site-1/custom/multi-client-sim.py", line 69, in main
#     new_params, steps = update_model(
#                         ^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/src/clients/memphis/client.py", line 67, in update_model
#     cost = loss(output['logits'], labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/loss.py", line 850, in forward
#     return F.binary_cross_entropy_with_logits(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/functional.py", line 3589, in binary_cross_entropy_with_logits
#     raise ValueError(
# ValueError: Target size (torch.Size([16])) must be the same as input size (torch.Size([16, 1]))
#
# 2026-01-09 02:17:22,418 - ERROR - ask to abort job: reason: train' is aborted, abort_signal_triggered
# 2026-01-09 02:17:22,422 - ERROR - Aborting current RUN due to FATAL_SYSTEM_ERROR received: Result from site-1 is bad, error code: TASK_ABORTED. ScatterAndGather exiting at round 0.
# 2026-01-09 02:17:22,533 - ERROR - Traceback (most recent call last):
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_common/executors/task_script_runner.py", line 54, in run
#     runpy.run_path(self.script_full_path, run_name="__main__")
#   File "<frozen runpy>", line 287, in run_path
#   File "<frozen runpy>", line 98, in _run_module_code
#   File "<frozen runpy>", line 88, in _run_code
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-2/simulate_job/app_site-2/custom/multi-client-sim.py", line 90, in <module>
#     main()
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-2/simulate_job/app_site-2/custom/multi-client-sim.py", line 69, in main
#     new_params, steps = update_model(
#                         ^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/src/clients/san_diego/client.py", line 85, in update_model
#     cost = loss(output['logits'], progression_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/loss.py", line 850, in forward
#     return F.binary_cross_entropy_with_logits(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/functional.py", line 3589, in binary_cross_entropy_with_logits
#     raise ValueError(
# ValueError: Target size (torch.Size([32])) must be the same as input size (torch.Size([32, 1]))
#
# 2026-01-09 02:17:22,534 - ERROR - fire abort event
# 2026-01-09 02:17:22,534 - ERROR - ask to abort job: reason: '/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-2/simulate_job/app_site-2/custom/multi-client-sim.py' is aborted, Traceback (most recent call last):
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_common/executors/task_script_runner.py", line 54, in run
#     runpy.run_path(self.script_full_path, run_name="__main__")
#   File "<frozen runpy>", line 287, in run_path
#   File "<frozen runpy>", line 98, in _run_module_code
#   File "<frozen runpy>", line 88, in _run_code
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-2/simulate_job/app_site-2/custom/multi-client-sim.py", line 90, in <module>
#     main()
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-2/simulate_job/app_site-2/custom/multi-client-sim.py", line 69, in main
#     new_params, steps = update_model(
#                         ^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/src/clients/san_diego/client.py", line 85, in update_model
#     cost = loss(output['logits'], progression_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/loss.py", line 850, in forward
#     return F.binary_cross_entropy_with_logits(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/functional.py", line 3589, in binary_cross_entropy_with_logits
#     raise ValueError(
# ValueError: Target size (torch.Size([32])) must be the same as input size (torch.Size([32, 1]))
#
# 2026-01-09 02:17:22,566 - INFO - Abort signal received. Exiting at round 0.
# Exception in thread Thread-2 (run):
# Traceback (most recent call last):
#   File "/Users/tyleryang/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/Users/tyleryang/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_common/executors/task_script_runner.py", line 71, in run
#     raise e
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_common/executors/task_script_runner.py", line 54, in run
#     runpy.run_path(self.script_full_path, run_name="__main__")
#   File "<frozen runpy>", line 287, in run_path
#   File "<frozen runpy>", line 98, in _run_module_code
#   File "<frozen runpy>", line 88, in _run_code
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-1/simulate_job/app_site-1/custom/multi-client-sim.py", line 90, in <module>
#     main()
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-1/simulate_job/app_site-1/custom/multi-client-sim.py", line 69, in main
#     new_params, steps = update_model(
#                         ^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/src/clients/memphis/client.py", line 67, in update_model
#     cost = loss(output['logits'], labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/loss.py", line 850, in forward
#     return F.binary_cross_entropy_with_logits(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/functional.py", line 3589, in binary_cross_entropy_with_logits
#     raise ValueError(
# ValueError: Target size (torch.Size([16])) must be the same as input size (torch.Size([16, 1]))
# Exception in thread Thread-2 (run):
# Traceback (most recent call last):
#   File "/Users/tyleryang/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/Users/tyleryang/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_common/executors/task_script_runner.py", line 71, in run
#     raise e
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_common/executors/task_script_runner.py", line 54, in run
#     runpy.run_path(self.script_full_path, run_name="__main__")
#   File "<frozen runpy>", line 287, in run_path
#   File "<frozen runpy>", line 98, in _run_module_code
#   File "<frozen runpy>", line 88, in _run_code
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-2/simulate_job/app_site-2/custom/multi-client-sim.py", line 90, in <module>
#     main()
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-2/simulate_job/app_site-2/custom/multi-client-sim.py", line 69, in main
#     new_params, steps = update_model(
#                         ^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/src/clients/san_diego/client.py", line 85, in update_model
#     cost = loss(output['logits'], progression_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/modules/loss.py", line 850, in forward
#     return F.binary_cross_entropy_with_logits(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/torch/nn/functional.py", line 3589, in binary_cross_entropy_with_logits
#     raise ValueError(
# ValueError: Target size (torch.Size([32])) must be the same as input size (torch.Size([32, 1]))
# 2026-01-09 02:17:22,915 - ERROR - ask to abort job: reason: train' is aborted, abort_signal_triggered
# 2026-01-09 02:17:22,917 - WARNING - ask to stop job: reason: END_RUN received
# 2026-01-09 02:17:24,469 - WARNING - ask to stop job: reason: END_RUN received
#
# Note, get_status returns None in SimEnv. The simulation logs can be found at /tmp/nvflare/simulation/MEM_SAN_FedCollab
# Job Status is: None
# Result can be found in : /tmp/nvflare/simulation/MEM_SAN_FedCollab

# %% [markdown]
# #### 5. Visualize the Training
# You can use TensorBoard to show the experiment tracking curves by running
#
# ```bash
# tensorboard --bind_all --logdir /tmp/nvflare/simulation/MEM_SAN_FedCollab
# ```
# in another terminal or directly show the training curves in the next notebook cell.

# %%
# asked Holger, logs are in server/simulate_job/tb_events
# they were empty because of the 2000 datapt condition.
# %load_ext tensorboard
# %tensorboard --bind_all --logdir /tmp/nvflare/simulation/MEM_SAN_FedCollab # also had this stuck as hello-pt
# Out:
#       <iframe id="tensorboard-frame-39196c4d465405af" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-39196c4d465405af");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
