# %% [markdown]
# Modified from the [NVFlare Hello PyTorch example](https://github.com/NVIDIA/NVFlare/tree/main/examples/hello-world/hello-pt)

# %% [markdown]
# ## Run an NVFlare Job
# Now that we have defined the FedAvg controller to run our federated compute workflow on the FL server, and our client training script to receive the global models, run local training, and send the results back to the FL server, we can put everything together using NVFlare's Job API.

# %% [markdown]
# #### 2. Define a FedJob Recipe

# %%
from server.model import FusionNet

from nvflare.app_opt.pt.recipes.fedavg import FedAvgRecipe
from nvflare.recipe import SimEnv
from nvflare.recipe import add_experiment_tracking
import torch 
n_clients = 2
num_rounds = 4
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model = FusionNet().to(device)

recipe = FedAvgRecipe(
    name="MEM_SAN_FedCollab", # MEM - Memphis, SAN - San Diego
    min_clients=n_clients,
    num_rounds=num_rounds,
    initial_model=model,
    train_script="client.py",
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 12
#       9 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#      10 model = model = FusionNet().to(device)
# ---> 12 recipe = FedAvgRecipe(
#      13     name="MEM_SAN_FedCollab", # MEM - Memphis, SAN - San Diego
#      14     min_clients=n_clients,
#      15     num_rounds=num_rounds,
#      16     initial_model=model,
#      17     train_script="client.py",
#      18 )
#
# File ~/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_opt/pt/recipes/fedavg.py:185, in FedAvgRecipe.__init__(self, name, initial_model, min_clients, num_rounds, train_script, train_args, aggregator, aggregator_data_kind, launch_external_process, command, server_expected_format, params_transfer_type)
#     175 # Add clients
#     176 executor = ScriptRunner(
#     177     script=self.train_script,
#     178     script_args=self.train_args,
#    (...)    183     params_transfer_type=self.params_transfer_type,
#     184 )
# --> 185 job.to_clients(executor)
#     187 Recipe.__init__(self, job)
#
# File ~/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/job_config/api.py:506, in FedJob.to_clients(self, obj, id, **kwargs)
#     503 if isinstance(obj, Controller):
#     504     raise ValueError('Use `job.to(controller, "server")` or `job.to_server(controller)` for Controllers.')
# --> 506 return self.to(obj=obj, target=ALL_SITES, id=id, **kwargs)
#
# File ~/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/job_config/api.py:310, in FedJob.to(self, obj, target, id, **kwargs)
#     308 if add_to_job_method is not None:
#     309     ctx = JobCtx(obj, target, id)
# --> 310     result = add_to_job_method(self, ctx, **kwargs)
#     311 else:
#     312     # basic object
#     313     result = app.add_component(obj, id)
#
# File ~/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/job_config/script_runner.py:265, in BaseScriptRunner.add_to_fed_job(self, job, ctx, **kwargs)
#     252     executor = (
#     253         self._executor
#     254         if self._executor
#    (...)    261         )
#     262     )
#     263     job.add_executor(executor, tasks=tasks, ctx=ctx)
# --> 265 job.add_resources(resources=[self._script], ctx=ctx)
#     266 return comp_ids
#
# File ~/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/job_config/api.py:434, in FedJob.add_resources(self, resources, ctx)
#     424 """Add resources to the job. To be used by job component programmer.
#     425
#     426 Args:
#    (...)    431
#     432 """
#     433 app = self._get_app(ctx)
# --> 434 app.add_resources(resources)
#
# File ~/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/job_config/api.py:137, in FedApp.add_resources(self, resources)
#     128 """Add resources to the job. To be used by job component programmer.
#     129
#     130 Args:
#    (...)    134
#     135 """
#     136 for r in resources:
# --> 137     self._add_resource(r)
#
# File ~/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/job_config/api.py:125, in FedApp._add_resource(self, resource)
#     123     self.add_external_script(resource)
#     124 else:
# --> 125     raise ValueError(f"cannot add resource: invalid resource {resource}: it must be either a directory or file")
#
# ValueError: cannot add resource: invalid resource client.py: it must be either a directory or file

# %% [markdown]
# #### 3. Add experiment tracking

# %%
add_experiment_tracking(recipe, tracking_type="tensorboard")

# %% [markdown]
# #### 4. Run Job
# Here, we run the job in a simulation environment.

# %%
env = SimEnv(num_clients=n_clients)
run = recipe.execute(env)
print()
print("Job Status is:", run.get_status())
print("Result can be found in :", run.get_result())
print()

# %% [markdown]
# #### 5. Visualize the Training
# You can use TensorBoard to show the experiment tracking curves by running
#
# ```bash
# tensorboard --bind_all --logdir /tmp/nvflare/simulation/MEM_SAN_FedCollab
# ```
# in another terminal or directly show the training curves in the next notebook cell.

# %%
# asked Holger, logs are in server/simulate_job/tb_events
# they were empty because of the 2000 datapt condition.
# %load_ext tensorboard
# %tensorboard --bind_all --logdir /tmp/nvflare/simulation/MEM_SAN_FedCollab # also had this stuck as hello-pt
