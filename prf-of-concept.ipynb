# %% [markdown]
# # Getting Started with NVFlare (PyTorch)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/NVIDIA/NVFlare/blob/main/examples/hello-world/hello-pt/hello-pt.ipynb)
#
# NVFlare is an open-source framework that allows researchers and
# data scientists to seamlessly move their machine learning and deep
# learning workflows into a federated paradigm.

# %% [markdown]
# ## Federated Averaging with NVFlare
# Given the flexible controller and executor concepts, it is easy to implement different computing & communication patterns with NVFlare, such as [FedAvg](https://proceedings.mlr.press/v54/mcmahan17a?ref=https://githubhelp.com) and [cyclic weight transfer](https://academic.oup.com/jamia/article/25/8/945/4956468).
#
# The controller's `run()` routine is responsible for assigning tasks and processing task results from the Executors.

# %% [markdown]
# ### Server Code
# In federated averaging, the server code is responsible for distributing the global model and aggregating model updates from clients.
#
# First, we provide a robust implementation of the [FedAvg](https://proceedings.mlr.press/v54/mcmahan17a?ref=https://githubhelp.com) algorithm with NVFlare.
#
# The server implements these main steps:
# 1. FL server initializes an initial model.
# 2. For each round (global iteration):
#     - FL server samples available clients.
#     - FL server sends the global model to clients and waits for their updates.
#     - FL server aggregates all the `results` and produces a new global model.
#
# In this example, we will directly use the default federated averaging algorithm provided by NVFlare utilizing the [FedAvgRecipe](https://nvflare.readthedocs.io/en/main/apidocs/nvflare.app_opt.pt.recipes.fedavg.html#nvflare.app_opt.pt.recipes.fedavg.FedAvgRecipe) for PyTorch.
#
# There is no need to defined a customized server code for this example.

# %% [markdown]
# ### Client Code
# We take a CIFAR-10 example directly from [PyTorch website](https://github.com/pytorch/tutorials/blob/main/beginner_source/blitz/cifar10_tutorial.py) with some minor modifications, such as removing comments, move the network to [src/net.py](src/net.py), and add a main method and GPU support. The original code can be found at [cifar10_original.py](../../hello-world/ml-to-fl/pt/code/cifar10_original.py).

# %% [markdown]
# Now, we need to adapt this centralized training code to something that can run in a federated setting.
#
# On the client side, the training workflow is as follows:
# 1. Receive the model from the FL server.
# 2. Perform local training on the received global model
# and/or evaluate the received global model for model
# selection.
# 3. Send the new model back to the FL server.

# %% [markdown]
# Using NVFlare's client API, we can easily adapt machine learning code that was written for centralized training and apply it in a federated scenario.
# For a general use case, there are three essential methods to achieve this using the Client API :
# - `init()`: Initializes NVFlare Client API environment.
# - `receive()`: Receives model from the FL server.
# - `send()`: Sends the model to the FL server.

# %% [markdown]
# ## Run an NVFlare Job
# Now that we have defined the FedAvg controller to run our federated compute workflow on the FL server, and our client training script to receive the global models, run local training, and send the results back to the FL server, we can put everything together using NVFlare's Job API.

# %% [markdown]
# #### 2. Define a FedJob Recipe

# %%
from model import SimpleNetwork

from nvflare.app_opt.pt.recipes.fedavg import FedAvgRecipe
from nvflare.recipe import SimEnv
# from nvflare.recipe import add_experiment_tracking
import torch 
n_clients = 2
num_rounds = 2
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleNetwork(rna_dim=19359, clinical_dim=13).to(device)

recipe = FedAvgRecipe(
    name="hello-multimodal",
    min_clients=n_clients,
    num_rounds=num_rounds,
    initial_model=model,
    train_script="client.py",
)

# %% [markdown]
# #### 3. Add experiment tracking

# %%
# add_experiment_tracking(recipe, tracking_type="tensorboard")

# %% [markdown]
# #### 4. Run Job
# Here, we run the job in a simulation environment.

# %%
env = SimEnv(num_clients=n_clients)
run = recipe.execute(env)
print()
print("Job Status is:", run.get_status())
print("Result can be found in :", run.get_result())
print()
# Out:
# 2026-01-08 12:02:04,810 - INFO - model selection weights control: {}
# 2026-01-08 12:02:05,410 - INFO - Tensorboard records can be found in /tmp/nvflare/simulation/hello-multimodal/server/simulate_job/tb_events you can view it using `tensorboard --logdir=/tmp/nvflare/simulation/hello-multimodal/server/simulate_job/tb_events`
# 2026-01-08 12:02:05,410 - INFO - Initializing ScatterAndGather workflow for Federated Averaging.
# 2026-01-08 12:02:05,411 - INFO - Both source_ckpt_file_full_name and ckpt_preload_path are not provided. Using the default model weights initialized on the persistor side.
# 2026-01-08 12:02:05,411 - INFO - Beginning ScatterAndGather training phase.
# 2026-01-08 12:02:05,411 - INFO - Round 0 started.
# 2026-01-08 12:02:09,040 - INFO - start task run() with full path: /tmp/nvflare/simulation/hello-multimodal/site-2/simulate_job/app_site-2/custom/client.py
# 2026-01-08 12:02:09,043 - INFO - start task run() with full path: /tmp/nvflare/simulation/hello-multimodal/site-1/simulate_job/app_site-1/custom/client.py
# 2026-01-08 12:02:09,369 - INFO - execute for task (train)
# 2026-01-08 12:02:09,369 - INFO - send data to peer
# 2026-01-08 12:02:09,369 - INFO - sending payload to peer
# 2026-01-08 12:02:09,369 - INFO - Waiting for result from peer
# 2026-01-08 12:02:09,380 - INFO - execute for task (train)
# 2026-01-08 12:02:09,380 - INFO - send data to peer
# 2026-01-08 12:02:09,380 - INFO - sending payload to peer
# 2026-01-08 12:02:09,381 - INFO - Waiting for result from peer
# 2026-01-08 12:02:09,605 - INFO - --- site-2: Training RNA modality ---
# 2026-01-08 12:02:09,605 - INFO - --- site-1: Training CLINICAL modality ---
# 2026-01-08 12:02:09,605 - INFO - site = site-2, current_round=0
# 2026-01-08 12:02:09,605 - INFO - site = site-1, current_round=0
# 2026-01-08 12:02:09,633 - INFO - Finished Training for site-1
# 2026-01-08 12:02:09,822 - INFO - site: site-1, sending model to server.
# 2026-01-08 12:02:10,099 - WARNING - Aggregation_weight missing for site-1 and set to default value, 1.0 This kind of message will show 10 times at most.
# 2026-01-08 12:02:10,117 - INFO - Contribution from site-1 ACCEPTED by the aggregator at round 0.
# 2026-01-08 12:02:11,385 - INFO - Finished Training for site-2
# 2026-01-08 12:02:11,571 - INFO - site: site-2, sending model to server.
# 2026-01-08 12:02:12,124 - WARNING - Aggregation_weight missing for site-2 and set to default value, 1.0 This kind of message will show 10 times at most.
# 2026-01-08 12:02:12,163 - INFO - Contribution from site-2 ACCEPTED by the aggregator at round 0.
# 2026-01-08 12:02:12,367 - INFO - Start aggregation.
# 2026-01-08 12:02:12,367 - INFO - aggregating 2 update(s) at round 0
# 2026-01-08 12:02:12,391 - INFO - End aggregation.
# 2026-01-08 12:02:12,391 - INFO - Start persist model on server.
# 2026-01-08 12:02:12,592 - INFO - End persist model on server.
# 2026-01-08 12:02:12,592 - INFO - Round 0 finished.
# 2026-01-08 12:02:12,618 - INFO - Round 1 started.
# 2026-01-08 12:02:12,901 - INFO - execute for task (train)
# 2026-01-08 12:02:12,901 - INFO - send data to peer
# 2026-01-08 12:02:12,901 - INFO - sending payload to peer
# 2026-01-08 12:02:12,901 - INFO - Waiting for result from peer
# 2026-01-08 12:02:13,378 - INFO - site = site-1, current_round=1
# 2026-01-08 12:02:13,403 - INFO - Finished Training for site-1
# 2026-01-08 12:02:13,521 - INFO - site: site-1, sending model to server.
# 2026-01-08 12:02:14,132 - WARNING - validation metric not existing in site-1
# 2026-01-08 12:02:14,133 - WARNING - Aggregation_weight missing for site-1 and set to default value, 1.0 This kind of message will show 10 times at most.
# 2026-01-08 12:02:14,149 - INFO - Contribution from site-1 ACCEPTED by the aggregator at round 1.
# 2026-01-08 12:02:14,398 - INFO - execute for task (train)
# 2026-01-08 12:02:14,398 - INFO - send data to peer
# 2026-01-08 12:02:14,398 - INFO - sending payload to peer
# 2026-01-08 12:02:14,399 - INFO - Waiting for result from peer
# 2026-01-08 12:02:14,603 - INFO - site = site-2, current_round=1
# 2026-01-08 12:02:16,329 - INFO - Finished Training for site-2
# 2026-01-08 12:02:16,436 - INFO - site: site-2, sending model to server.
# 2026-01-08 12:02:17,136 - WARNING - validation metric not existing in site-2
# 2026-01-08 12:02:17,137 - WARNING - Aggregation_weight missing for site-2 and set to default value, 1.0 This kind of message will show 10 times at most.
# 2026-01-08 12:02:17,176 - INFO - Contribution from site-2 ACCEPTED by the aggregator at round 1.
# 2026-01-08 12:02:17,311 - INFO - Start aggregation.
# 2026-01-08 12:02:17,312 - INFO - aggregating 2 update(s) at round 1
# 2026-01-08 12:02:17,331 - INFO - End aggregation.
# 2026-01-08 12:02:17,332 - INFO - Start persist model on server.
# 2026-01-08 12:02:17,446 - INFO - End persist model on server.
# 2026-01-08 12:02:17,447 - INFO - Round 1 finished.
# 2026-01-08 12:02:17,468 - INFO - Finished ScatterAndGather Training.
# 2026-01-08 12:02:19,238 - WARNING - ask to stop job: reason: END_RUN received
# 2026-01-08 12:02:19,239 - WARNING - ask to stop job: reason: END_RUN received
# 2026-01-08 12:02:19,466 - WARNING - request to stop the job for reason END_RUN received
# 2026-01-08 12:02:19,570 - WARNING - request to stop the job for reason END_RUN received
#
# Note, get_status returns None in SimEnv. The simulation logs can be found at /tmp/nvflare/simulation/hello-multimodal
# Job Status is: None
# Result can be found in : /tmp/nvflare/simulation/hello-multimodal

# %% [markdown]
# #### 5. Visualize the Training
# You can use TensorBoard to show the experiment tracking curves by running
#
# ```bash
# tensorboard --bind_all --logdir /tmp/nvflare/simulation/hello-pt
# ```
# in another terminal or directly show the training curves in the next notebook cell.

# %%
# asked Holger, logs are in server/simulate_job/tb_events
# they were empty because of the 2000 datapt condition.
# %load_ext tensorboard
# %tensorboard --bind_all --logdir /tmp/nvflare/simulation/hello-multimodal # also had this stuck as hello-pt
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6007 (pid 21556), started 0:00:04 ago. (Use '!kill 21556' to kill it.)
#       <iframe id="tensorboard-frame-da3857bb1f5eff57" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-da3857bb1f5eff57");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
